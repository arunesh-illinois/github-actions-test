# %% [markdown]
# # 🗺️ CyberGIS Test Notebook
#
# This notebook tests basic CyberGIS functionality including spatial data handling, mapping, and spatial operations using Python libraries such as `geopandas` and `folium`.

# %% [markdown]
# ## 📦 1. Install Required Libraries

# %%
# !pip install geopandas folium matplotlib geodatasets --quiet
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## 📚 2. Import Libraries

# %%
import geopandas as gpd
import folium
import matplotlib.pyplot as plt
from shapely.geometry import Point

# %% [markdown]
# ## 📍 3. Create Sample Point Data (GeoDataFrame)

# %%
data = {
    'name': ['Point A', 'Point B', 'Point C'],
    'latitude': [40.1106, 40.1138, 40.1042],
    'longitude': [-88.2073, -88.2272, -88.1986]
}
geometry = [Point(xy) for xy in zip(data['longitude'], data['latitude'])]
gdf_points = gpd.GeoDataFrame(data, geometry=geometry, crs='EPSG:4326')
gdf_points
# Out:
#       name  latitude  longitude                  geometry
# 0  Point A   40.1106   -88.2073  POINT (-88.2073 40.1106)
# 1  Point B   40.1138   -88.2272  POINT (-88.2272 40.1138)
# 2  Point C   40.1042   -88.1986  POINT (-88.1986 40.1042)

# %% [markdown]
# ## 🌍 4. Load World Map Data

# %%
import geopandas as gpd
import geodatasets

# Load the world countries dataset
world = gpd.read_file(geodatasets.get_path('naturalearth.land'))
world.head()
# Out:
# ...
#   featurecla  scalerank  min_zoom  \
# 0       Land          1       1.0
# 1       Land          1       1.0
# 2       Land          1       0.0
# 3       Land          1       1.0
# 4       Land          1       1.0
#
#                                             geometry
# 0  POLYGON ((-59.57209 -80.04018, -59.86585 -80.5...
# 1  POLYGON ((-159.20818 -79.49706, -161.1276 -79....
# 2  POLYGON ((-45.15476 -78.04707, -43.92083 -78.4...
# 3  POLYGON ((-121.21151 -73.50099, -119.91885 -73...
# 4  POLYGON ((-125.55957 -73.48135, -124.03188 -73...

# %% [markdown]
# ## 🖼️ 5. Plot Points on Static World Map (Matplotlib)

# %%
fig, ax = plt.subplots(figsize=(10, 6))
world.plot(ax=ax, color='lightgrey')
gdf_points.plot(ax=ax, color='red', markersize=100)
plt.title('Sample Points on World Map')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# ## ✅ Test Complete
#
# You’ve successfully tested spatial operations, visualization, and basic GIS capabilities in Python!
